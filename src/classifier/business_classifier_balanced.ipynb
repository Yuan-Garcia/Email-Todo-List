# %%
import pandas as pd
import random

# Convert dict to lists
emails = list(emails_and_labels.keys())
labels_list = list(emails_and_labels.values())

# Shuffle the data
combined = list(zip(emails, labels_list))
random.seed(42)
random.shuffle(combined)
emails_shuffled, labels_shuffled = zip(*combined)

# Create DataFrame
df = pd.DataFrame({
    "email": list(emails_shuffled),
    "label": list(labels_shuffled)
})

print(df.head())
print(f"\nDataset shape: {df.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 import random
#       4 # Convert dict to lists
# ----> 5 emails = list(emails_and_labels.keys())
#       6 labels_list = list(emails_and_labels.values())
#       8 # Shuffle the data
#
# NameError: name 'emails_and_labels' is not defined

# %%
# Out:
# Train: 19,144 samples
# Val: 6,382 samples
# Test: 6,382 samples

# %%
# Out:
# /Users/ethansandoval/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...
# Map:   0%|          | 0/6382 [00:00<?, ? examples/s]

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 training_args = TrainingArguments(
#       2     output_dir="./results_balanced",
#       3     num_train_epochs=10,
#       4     logging_strategy="epoch",
#       5     evaluation_strategy="epoch",
#       6     save_strategy="epoch",
#       7     save_total_limit=2,
#       8     load_best_model_at_end=True,
#       9     metric_for_best_model="eval_f1",
#      10     greater_is_better=True,
#      11     report_to="none",
#      12     learning_rate=3e-5,
#      13     per_device_train_batch_size=16,
#      14     per_device_eval_batch_size=32,
#      15     fp16=True,
#      16     warmup_steps=500,
#      17     weight_decay=0.05,
#      18 )
#      20 trainer = Trainer(
#      21     model_init=model_init,
#      22     args=training_args,
#    (...)
# ...

# %%
# Save the trained model for inference
trainer.save_model("./my_email_classifier")
tokenizer.save_pretrained("./my_email_classifier")
print("Model saved to ./my_email_classifier")
print("Use classify_email.py for inference")
